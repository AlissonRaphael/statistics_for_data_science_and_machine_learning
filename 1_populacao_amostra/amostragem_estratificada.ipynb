# %%
import pandas as pd
import random
import numpy as np
from sklearn.model_selection import StratifiedShuffleSplit

# %%
dataset = pd.read_csv('../0_datasets/census.csv')

# %%
dataset.shape
# Out:
# (32561, 15)

# %%
dataset.head()
# Out:
#    age          workclass  final-weight   education  education-num  \
# 0   39          State-gov         77516   Bachelors             13
# 1   50   Self-emp-not-inc         83311   Bachelors             13
# 2   38            Private        215646     HS-grad              9
# 3   53            Private        234721        11th              7
# 4   28            Private        338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loos  hour-per-week  native-country  income
# 0          2174             0             40   United-States   <=50K
# 1             0             0             13   United-States   <=50K
# 2             0             0             40   United-States   <=50K
# 3             0             0             40   United-States   <=50K
# 4             0             0             40            Cuba   <=50K

# %%
dataset.tail()
# Out:
#        age      workclass  final-weight    education  education-num  \
# 32556   27        Private        257302   Assoc-acdm             12
# 32557   40        Private        154374      HS-grad              9
# 32558   58        Private        151910      HS-grad              9
# 32559   22        Private        201490      HS-grad              9
# 32560   52   Self-emp-inc        287927      HS-grad              9
#
#             marital-status          occupation relationship    race      sex  \
# 32556   Married-civ-spouse        Tech-support         Wife   White   Female
# 32557   Married-civ-spouse   Machine-op-inspct      Husband   White     Male
# 32558              Widowed        Adm-clerical    Unmarried   White   Female
# 32559        Never-married        Adm-clerical    Own-child   White     Male
# 32560   Married-civ-spouse     Exec-managerial         Wife   White   Female
#
#        capital-gain  capital-loos  hour-per-week  native-country  income
# 32556             0             0             38   United-States   <=50K
# 32557             0             0             40   United-States    >50K
# 32558             0             0             40   United-States   <=50K
# 32559             0             0             20   United-States   <=50K
# 32560         15024             0             40   United-States    >50K

# %% [markdown]
# ### Amostragem estradificada

# %%
dataset['income'].value_counts()
# Out:
#  <=50K    24720
#  >50K      7841
# Name: income, dtype: int64

# %%
7841 / len(dataset), 24720 / len(dataset)
# Out:
# (0.2408095574460244, 0.7591904425539756)

# %%
7841 / len(dataset) + 24720 / len(dataset)
# Out:
# 1.0

# %%
100 / len(dataset)
# Out:
# 0.0030711587481956942

# %%
split = StratifiedShuffleSplit(test_size=0.0030711587481956942)
for x, y in split.split(dataset, dataset['income']):
    df_x = dataset.iloc[x]
    df_y = dataset.iloc[y]

# %%
df_x.head()
# Out:
#        age          workclass  final-weight      education  education-num  \
# 2676    62                  ?        139391   Some-college             10
# 29576   45   Self-emp-not-inc        102771      Bachelors             13
# 15998   41        Federal-gov        371382   Some-college             10
# 4064    58       Self-emp-inc        104333        HS-grad              9
# 30598   41            Private         29702      Assoc-voc             11
#
#             marital-status         occupation    relationship    race    sex  \
# 2676    Married-civ-spouse                  ?         Husband   White   Male
# 29576   Married-civ-spouse   Transport-moving         Husband   White   Male
# 15998   Married-civ-spouse    Exec-managerial         Husband   Black   Male
# 4064              Divorced              Sales   Not-in-family   White   Male
# 30598        Never-married       Craft-repair   Not-in-family   White   Male
#
#        capital-gain  capital-loos  hour-per-week  native-country  income
# 2676              0             0             24   United-States   <=50K
# 29576             0             0             40   United-States    >50K
# 15998             0             0             40   United-States    >50K
# 4064              0             0             50   United-States   <=50K
# 30598             0             0             30   United-States   <=50K

# %%
df_y.head()
# Out:
#        age          workclass  final-weight      education  education-num  \
# 3754    46   Self-emp-not-inc        236852      Bachelors             13
# 3448    50   Self-emp-not-inc         44368        HS-grad              9
# 17909   50            Private        275181        5th-6th              3
# 26770   40            Private        126845   Some-college             10
# 8306    25            Private        212800   Some-college             10
#
#             marital-status      occupation    relationship    race      sex  \
# 3754    Married-civ-spouse           Sales         Husband   White     Male
# 3448    Married-civ-spouse           Sales         Husband   White     Male
# 17909             Divorced   Other-service   Not-in-family   White     Male
# 26770   Married-civ-spouse    Adm-clerical         Husband   White     Male
# 8306         Never-married           Sales       Own-child   White   Female
#
#        capital-gain  capital-loos  hour-per-week  native-country  income
# 3754              0             0             45   United-States    >50K
# 3448          15024             0             55     El-Salvador    >50K
# 17909             0             0             37            Cuba   <=50K
# 26770             0             0             40   United-States    >50K
# 8306              0             0             40   United-States   <=50K

# %%
df_y['income'].value_counts()
# Out:
#  <=50K    76
#  >50K     24
# Name: income, dtype: int64
